# %%
# All the imports
import numpy as np
import skimage as ski
print(np.__file__)
print(np.__version__)
print(ski.__version__)
from __future__ import print_function
import keras
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten
from keras.layers import Conv2D, MaxPooling2D
from keras import backend as K

import matplotlib.pyplot as plt

from __future__ import print_function

import keras
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Dense, Dropout
from keras.optimizers import RMSprop
import tensorflow as tf
from skimage.transform import resize
from graphviz import Graph, render
from utils.netviz import NetViz
from utils.mnistutil import MNISTUitl
(A, Ay), (B, By) = mnist.load_data()
x = A[1]
print(x.shape)
xr = resize(x, (7, 7))
print(xr.shape)
plt.imshow(xr)
plt.show()
plt.imshow(x)
plt.show()
# Out:
# /Users/mislam/anaconda/lib/python3.6/site-packages/numpy/__init__.py
# 1.16.2
# 0.14.2
# /Users/mislam/anaconda/lib/python3.6/site-packages/h5py/__init__.py:34: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.
# (28, 28)
# (7, 7)
# /Users/mislam/anaconda/lib/python3.6/site-packages/skimage/transform/_warps.py:105: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# /Users/mislam/anaconda/lib/python3.6/site-packages/skimage/transform/_warps.py:110: UserWarning: Anti-aliasing will be enabled by default in skimage 0.15 to avoid aliasing artifacts when down-sampling images.
#   warn("Anti-aliasing will be enabled by default in skimage 0.15 to "

# %%
from utils.netviz import NetViz
mn = MNISTUitl()
viz = NetViz()

# %%
X, Y, x, y = mn.getdata2(0,0,7,7)
X.shape
# Out:
# /Users/mislam/anaconda/lib/python3.6/site-packages/skimage/transform/_warps.py:110: UserWarning: Anti-aliasing will be enabled by default in skimage 0.15 to avoid aliasing artifacts when down-sampling images.
#   warn("Anti-aliasing will be enabled by default in skimage 0.15 to "
# (60000, 7, 7)

# %%
print(X.shape,Y.shape, x.shape,y.shape)
# Out:
# (60000, 7, 7) (60000,) (980, 7, 7) (980,)

# %%
nm , xt, yt = mn.train2(X, Y, x,y,7,7,10,100)
# Out:
# x_train shape: (60000, 7, 7, 1)
# (60000, 7, 7, 1) 60000 train samples (60000,)
# 980 test samples
# (60000,) (60000,)
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# Input (Flatten)              (None, 49)                0
# _________________________________________________________________
# H (Dense)                    (None, 14)                700
# _________________________________________________________________
# output (Dense)               (None, 10)                150
# =================================================================
# Total params: 850
# Trainable params: 850
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/100
# 60000/60000 [==============================] - 1s 23us/step - loss: 2.2871 - acc: 0.1296
# Epoch 2/100
# 60000/60000 [==============================] - 1s 21us/step - loss: 2.1938 - acc: 0.2818
# Epoch 3/100
# 60000/60000 [==============================] - 1s 20us/step - loss: 2.0378 - acc: 0.3781
# Epoch 4/100
# 60000/60000 [==============================] - 1s 21us/step - loss: 1.8765 - acc: 0.4093
# Epoch 5/100
# 60000/60000 [==============================] - 1s 20us/step - loss: 1.7358 - acc: 0.4366
# Epoch 6/100
# 60000/60000 [==============================] - 1s 20us/step - loss: 1.6220 - acc: 0.4602
# Epoch 7/100
# 60000/60000 [==============================] - 1s 20us/step - loss: 1.5316 - acc: 0.4819
# Epoch 8/100
# 60000/60000 [==============================] - 1s 20us/step - loss: 1.4599 - acc: 0.4989
# Epoch 9/100
# 60000/60000 [==============================] - 1s 20us/step - loss: 1.4031 - acc: 0.5146
# Epoch 10/100
# 60000/60000 [==============================] - 1s 20us/step - loss: 1.3567 - acc: 0.5282
# Epoch 11/100
# 60000/60000 [==============================] - 1s 20us/step - loss: 1.3182 - acc: 0.5385
# Epoch 12/100
# 60000/60000 [==============================] - 1s 20us/step - loss: 1.2856 - acc: 0.5489
# Epoch 13/100
# 60000/60000 [==============================] - 1s 20us/step - loss: 1.2571 - acc: 0.5593
# Epoch 14/100
# 60000/60000 [==============================] - 1s 20us/step - loss: 1.2320 - acc: 0.5666
# Epoch 15/100
# 60000/60000 [==============================] - 1s 20us/step - loss: 1.2095 - acc: 0.5745
# Epoch 16/100
# 60000/60000 [==============================] - 1s 20us/step - loss: 1.1889 - acc: 0.5820
# Epoch 17/100
# 60000/60000 [==============================] - 1s 20us/step - loss: 1.1699 - acc: 0.5899
# Epoch 18/100
# 60000/60000 [==============================] - 1s 20us/step - loss: 1.1524 - acc: 0.5946
# Epoch 19/100
# 60000/60000 [==============================] - 1s 20us/step - loss: 1.1359 - acc: 0.6016
# Epoch 20/100
# 60000/60000 [==============================] - 1s 21us/step - loss: 1.1201 - acc: 0.6076
# Epoch 21/100
# 60000/60000 [==============================] - 1s 20us/step - loss: 1.1052 - acc: 0.6130
# Epoch 22/100
# 60000/60000 [==============================] - 1s 20us/step - loss: 1.0908 - acc: 0.6204
# Epoch 23/100
# 60000/60000 [==============================] - 1s 20us/step - loss: 1.0767 - acc: 0.6258
# Epoch 24/100
# 60000/60000 [==============================] - 1s 20us/step - loss: 1.0633 - acc: 0.6315
# Epoch 25/100
# 60000/60000 [==============================] - 1s 20us/step - loss: 1.0503 - acc: 0.6368
# Epoch 26/100
# 60000/60000 [==============================] - 1s 20us/step - loss: 1.0377 - acc: 0.6420
# Epoch 27/100
# 60000/60000 [==============================] - 1s 20us/step - loss: 1.
100
# 60000/60000 [==============================] - 1s 21us/step - loss: 0.8118 - acc: 0.7295
# Epoch 86/100
# 60000/60000 [==============================] - 1s 21us/step - loss: 0.8105 - acc: 0.7300
# Epoch 87/100
# 60000/60000 [==============================] - 1s 20us/step - loss: 0.8089 - acc: 0.7319
# Epoch 88/100
# 60000/60000 [==============================] - 1s 20us/step - loss: 0.8076 - acc: 0.7314
# Epoch 89/100
# 60000/60000 [==============================] - 1s 21us/step - loss: 0.8060 - acc: 0.7321
# Epoch 90/100
# 60000/60000 [==============================] - 1s 20us/step - loss: 0.8044 - acc: 0.7328
# Epoch 91/100
# 60000/60000 [==============================] - 1s 20us/step - loss: 0.8031 - acc: 0.7332
# Epoch 92/100
# 60000/60000 [==============================] - 1s 20us/step - loss: 0.8019 - acc: 0.7341
# Epoch 93/100
# 60000/60000 [==============================] - 1s 21us/step - loss: 0.8005 - acc: 0.7346
# Epoch 94/100
# 60000/60000 [==============================] - 1s 21us/step - loss: 0.7990 - acc: 0.7355
# Epoch 95/100
# 60000/60000 [==============================] - 1s 20us/step - loss: 0.7976 - acc: 0.7359
# Epoch 96/100
# 60000/60000 [==============================] - 1s 21us/step - loss: 0.7960 - acc: 0.7366
# Epoch 97/100
# 60000/60000 [==============================] - 1s 21us/step - loss: 0.7949 - acc: 0.7372
# Epoch 98/100
# 60000/60000 [==============================] - 1s 20us/step - loss: 0.7935 - acc: 0.7381
# Epoch 99/100
# 60000/60000 [==============================] - 1s 21us/step - loss: 0.7919 - acc: 0.7382
# Epoch 100/100
# 60000/60000 [==============================] - 1s 20us/step - loss: 0.7906 - acc: 0.7387

# %%
s = 35
e = 36
x1 = xt[ s:e]
y1 = yt[ s:e]
print(y1)
print(x.shape)
print(viz)
#dot, A, g = viz.vispredict(nm,x1,y1,7,7)
#print(nm.predict(x1),y1)
#dot
dot8, A = viz.vispredictwithlabel(nm,x1,y1,7,7)
print(nm.predict(x1),y1)
dot8
# Out:
# [0]
# (980, 7, 7)
# <utils.netviz.NetViz object at 0x1c2f1eb9b0>
# (49, 14)
# 0.0039023452 1.1637933 0.9966718
# (14,)  Here
# 0.13547201 -0.11255072 MINMAX W
# 10.376657 -17.91691 MINMAX W
# {'n3', 'n2', 'p4', 'p0', 'n1', 'n4', 'p3', 'n5', 'p1', 'n0', 'p2'} {'n3', 'n2', 'n1', 'n4', 'n5', 'n0'}
# [[9.9667180e-01 1.5752045e-13 8.2766812e-05 1.2541730e-03 9.5481347e-08
#   1.9598396e-03 2.7820955e-05 1.2670544e-07 3.2626263e-06 6.5606280e-08]] [0]

# %%
ad_zero10 = plt.imread("attacks/FGSM/zero_new_adv13.jpg")

# %%
xo = resize(ad_zero10, (7, 7))


y0 = [0]
print(y1)
xo = xo.reshape(1,7,7,1)
xo = xo/255
doto, A = viz.vispredictwithlabel(nm,xo,0,7,7)
print(nm.predict(xo),y1)
doto
# Out:
# [0]
# (49, 14)
# 0.0032372164552095374 0.8667358716023013 0.818442044342581
# (14,)  Here
# 0.11189485618124914 -0.0929627152985217 MINMAX W
# 10.515826735624108 -13.343631410108522 MINMAX W
# {'n3', 'n2', 'p4', 'p0', 'n1', 'n4', 'n5', 'p1', 'n0', 'p2'} {'n3', 'n2', 'n1', 'n4', 'n5', 'n0'}
# [[8.1844199e-01 2.9230810e-08 1.3892440e-01 1.3999574e-02 3.6105061e-07
#   2.2516612e-02 4.6679089e-03 4.9640086e-08 1.4489131e-03 1.2114597e-07]] [0]
# /Users/mislam/anaconda/lib/python3.6/site-packages/skimage/transform/_warps.py:105: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# /Users/mislam/anaconda/lib/python3.6/site-packages/skimage/transform/_warps.py:110: UserWarning: Anti-aliasing will be enabled by default in skimage 0.15 to avoid aliasing artifacts when down-sampling images.
#   warn("Anti-aliasing will be enabled by default in skimage 0.15 to "
