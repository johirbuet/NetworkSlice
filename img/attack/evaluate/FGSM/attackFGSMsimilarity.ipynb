# %%
#from skimage.measure import structural_similarity as ssi
from skimage.measure import compare_ssim
import matplotlib.pyplot as plt
import numpy as np
import cv2
from pathlib import Path
def mse(imageA, imageB):
	# the 'Mean Squared Error' between the two images is the
	# sum of the squared difference between the two images;
	# NOTE: the two images must have the same dimension
	err = np.sum((imageA.astype("float") - imageB.astype("float")) ** 2)
	err /= float(imageA.shape[0] * imageA.shape[1])
	
	# return the MSE, the lower the error, the more "similar"
	# the two images are
	return err
for i in range(0,20):
    exist=os.path.isfile("zero/adv_zero_{0}.gv.png".format(i))
    if exist:
        i1 = cv2.imread("zero/adv_zero_{0}.gv.png".format(i))
        i2 = cv2.imread("zero/or_zero_{0}.gv.png".format(i))
        x1=cv2.resize(i1, (100, 50))
        x2=cv2.resize(i2, (100, 50))
        x=mse(x1,x2)
        #print(str(i)+"->"+str(x))
        print(x)
# Out:
# 17399.0592
# 12891.5806
# 11885.3396
# 12420.0126
# 18392.0124
# 13172.0634
# 15809.8628
# 17881.3406
# 17106.2466
# 17487.813
# 22185.9202
# 18035.2394
# 12241.3292

# %%
#from skimage.measure import structural_similarity as ssi
from skimage.measure import compare_ssim
import matplotlib.pyplot as plt
import numpy as np
import cv2
from pathlib import Path
def mse(imageA, imageB):
	# the 'Mean Squared Error' between the two images is the
	# sum of the squared difference between the two images;
	# NOTE: the two images must have the same dimension
	err = np.sum((imageA.astype("float") - imageB.astype("float")) ** 2)
	err /= float(imageA.shape[0] * imageA.shape[1])
	
	# return the MSE, the lower the error, the more "similar"
	# the two images are
	return err
for i in range(0,20):
    exist=os.path.isfile("one/adv_one_{0}.gv.png".format(i))
    if exist:
        i1 = cv2.imread("one/adv_one_{0}.gv.png".format(i))
        i2 = cv2.imread("one/or_one_{0}.gv.png".format(i))
        x1=cv2.resize(i1, (100, 50))
        x2=cv2.resize(i2, (100, 50))
        x=mse(x1,x2)
        #print(str(i)+"->"+str(x))
        print(x)
# Out:
# 17518.8136
# 22251.1246
# 11197.6968
# 20683.8168
# 24438.1034
# 21777.6284
# 22758.6348
# 20709.159
# 15915.2126
# 22250.7114
# 24422.8028
# 24225.2824
# 17580.855
# 18398.4878
# 22671.8026
# 24760.2236
# 23374.6148
# 20696.7558
# 18856.575

# %%
#from skimage.measure import structural_similarity as ssi
from skimage.measure import compare_ssim
import matplotlib.pyplot as plt
import numpy as np
import cv2
from pathlib import Path
def mse(imageA, imageB):
	# the 'Mean Squared Error' between the two images is the
	# sum of the squared difference between the two images;
	# NOTE: the two images must have the same dimension
	err = np.sum((imageA.astype("float") - imageB.astype("float")) ** 2)
	err /= float(imageA.shape[0] * imageA.shape[1])
	
	# return the MSE, the lower the error, the more "similar"
	# the two images are
	return err
for i in range(0,20):
    exist=os.path.isfile("two/adv_two_{0}.gv.png".format(i))
    if exist:
        i1 = cv2.imread("two/adv_two_{0}.gv.png".format(i))
        i2 = cv2.imread("two/or_two_{0}.gv.png".format(i))
        x1=cv2.resize(i1, (100, 50))
        x2=cv2.resize(i2, (100, 50))
        x=mse(x1,x2)
        #print(str(i)+"->"+str(x))
        print(x)
# Out:
# 16196.5126
# 19223.5308
# 19239.1488
# 10897.0238
# 17033.2488
# 20099.0456
# 20619.0422
# 14061.4514
# 19346.7378
# 11843.578
# 19664.6784
# 23091.199
# 18283.5544
# 20831.5624
# 21312.2414
# 16485.9602
# 13181.3706

# %%
#from skimage.measure import structural_similarity as ssi
from skimage.measure import compare_ssim
import matplotlib.pyplot as plt
import numpy as np
import cv2
from pathlib import Path
def mse(imageA, imageB):
	# the 'Mean Squared Error' between the two images is the
	# sum of the squared difference between the two images;
	# NOTE: the two images must have the same dimension
	err = np.sum((imageA.astype("float") - imageB.astype("float")) ** 2)
	err /= float(imageA.shape[0] * imageA.shape[1])
	
	# return the MSE, the lower the error, the more "similar"
	# the two images are
	return err
for i in range(0,20):
    exist=os.path.isfile("three/adv_three_{0}.gv.png".format(i))
    if exist:
        i1 = cv2.imread("three/adv_three_{0}.gv.png".format(i))
        i2 = cv2.imread("three/or_three_{0}.gv.png".format(i))
        x1=cv2.resize(i1, (100, 50))
        x2=cv2.resize(i2, (100, 50))
        x=mse(x1,x2)
        #print(str(i)+"->"+str(x))
        print(x)
# Out:
# 6572.0822
# 13094.0854
# 21744.295
# 21641.9106
# 21702.094
# 18902.6646
# 8782.7416

# %%
#from skimage.measure import structural_similarity as ssi
from skimage.measure import compare_ssim
import matplotlib.pyplot as plt
import numpy as np
import cv2
from pathlib import Path
def mse(imageA, imageB):
	# the 'Mean Squared Error' between the two images is the
	# sum of the squared difference between the two images;
	# NOTE: the two images must have the same dimension
	err = np.sum((imageA.astype("float") - imageB.astype("float")) ** 2)
	err /= float(imageA.shape[0] * imageA.shape[1])
	
	# return the MSE, the lower the error, the more "similar"
	# the two images are
	return err
for i in range(0,20):
    exist=os.path.isfile("four/adv_four_{0}.gv.png".format(i))
    if exist:
        i1 = cv2.imread("four/adv_four_{0}.gv.png".format(i))
        i2 = cv2.imread("four/or_four_{0}.gv.png".format(i))
        x1=cv2.resize(i1, (100, 50))
        x2=cv2.resize(i2, (100, 50))
        x=mse(x1,x2)
        #print(str(i)+"->"+str(x))
        print(x)
# Out:
# 19685.2132
# 20062.6006
# 17885.6084
# 12600.2622
# 19995.9524
# 16736.1312
# 18732.8232
# 6473.996
# 16281.0062
# 13858.3908
# 7744.8362
# 13065.0492

# %%
#from skimage.measure import structural_similarity as ssi
from skimage.measure import compare_ssim
import matplotlib.pyplot as plt
import numpy as np
import cv2
from pathlib import Path
def mse(imageA, imageB):
	# the 'Mean Squared Error' between the two images is the
	# sum of the squared difference between the two images;
	# NOTE: the two images must have the same dimension
	err = np.sum((imageA.astype("float") - imageB.astype("float")) ** 2)
	err /= float(imageA.shape[0] * imageA.shape[1])
	
	# return the MSE, the lower the error, the more "similar"
	# the two images are
	return err
for i in range(0,20):
    exist=os.path.isfile("five/adv_five_{0}.gv.png".format(i))
    if exist:
        i1 = cv2.imread("five/adv_five_{0}.gv.png".format(i))
        i2 = cv2.imread("five/or_five_{0}.gv.png".format(i))
        x1=cv2.resize(i1, (100, 50))
        x2=cv2.resize(i2, (100, 50))
        x=mse(x1,x2)
        #print(str(i)+"->"+str(x))
        print(x)
# Out:
# 18596.1386
# 21667.0228
# 17961.7602
# 6227.5676
# 18743.083
# 24884.4228
# 8784.4074
# 15175.6066
# 20582.6804
# 26682.3272
# 21011.5966
# 6196.392
# 24664.2714
# 6792.4328
# 19702.569
# 15981.2152
# 18129.0356
# 20967.407

# %%
#from skimage.measure import structural_similarity as ssi
from skimage.measure import compare_ssim
import matplotlib.pyplot as plt
import numpy as np
import cv2
from pathlib import Path
def mse(imageA, imageB):
	# the 'Mean Squared Error' between the two images is the
	# sum of the squared difference between the two images;
	# NOTE: the two images must have the same dimension
	err = np.sum((imageA.astype("float") - imageB.astype("float")) ** 2)
	err /= float(imageA.shape[0] * imageA.shape[1])
	
	# return the MSE, the lower the error, the more "similar"
	# the two images are
	return err
for i in range(0,20):
    exist=os.path.isfile("six/adv_six_{0}.gv.png".format(i))
    if exist:
        i1 = cv2.imread("six/adv_six_{0}.gv.png".format(i))
        i2 = cv2.imread("six/or_six_{0}.gv.png".format(i))
        x1=cv2.resize(i1, (100, 50))
        x2=cv2.resize(i2, (100, 50))
        x=mse(x1,x2)
        print(str(i)+"->"+str(x))
        #print(x)
# Out:
# 0->17451.5176
# 1->17416.4252
# 2->11197.7482
# 3->14094.0746
# 4->24163.9472
# 5->21542.3328
# 6->19265.4902
# 7->11145.5038
# 8->6783.4962
# 9->21564.388
# 10->21483.0056
# 11->18077.4632
# 12->11245.6536
# 13->18655.0234
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-32-61106fc9fecc> in <module>
#      21         i2 = cv2.imread("six/or_six_{0}.gv.png".format(i))
#      22         x1=cv2.resize(i1, (100, 50))
# ---> 23         x2=cv2.resize(i2, (100, 50))
#      24         x=mse(x1,x2)
#      25         print(str(i)+"->"+str(x))
#
# error: OpenCV(4.0.0) C:\projects\opencv-python\opencv\modules\imgproc\src\resize.cpp:3784: error: (-215:Assertion failed) !ssize.empty() in function 'cv::resize'

# %%
#from skimage.measure import structural_similarity as ssi
from skimage.measure import compare_ssim
import matplotlib.pyplot as plt
import numpy as np
import cv2
from pathlib import Path
def mse(imageA, imageB):
	# the 'Mean Squared Error' between the two images is the
	# sum of the squared difference between the two images;
	# NOTE: the two images must have the same dimension
	err = np.sum((imageA.astype("float") - imageB.astype("float")) ** 2)
	err /= float(imageA.shape[0] * imageA.shape[1])
	
	# return the MSE, the lower the error, the more "similar"
	# the two images are
	return err
for i in range(0,20):
    exist=os.path.isfile("seven/adv_seven_{0}.gv.png".format(i))
    if exist:
        i1 = cv2.imread("seven/adv_seven_{0}.gv.png".format(i))
        i2 = cv2.imread("seven/or_seven_{0}.gv.png".format(i))
        x1=cv2.resize(i1, (100, 50))
        x2=cv2.resize(i2, (100, 50))
        x=mse(x1,x2)
        #print(str(i)+"->"+str(x))
        print(x)
# Out:
# 18911.9434
# 19469.2486
# 19068.3874
# 15934.5178
# 11407.1698
# 23972.5394
# 16522.4162
# 6028.4462
# 17562.62
# 18103.52
# 5903.81
# 20498.7862
# 14250.427
# 12844.6638
# 7114.0356
# 15008.9808
# 21773.125

# %%
#from skimage.measure import structural_similarity as ssi
from skimage.measure import compare_ssim
import matplotlib.pyplot as plt
import numpy as np
import cv2
from pathlib import Path
def mse(imageA, imageB):
	# the 'Mean Squared Error' between the two images is the
	# sum of the squared difference between the two images;
	# NOTE: the two images must have the same dimension
	err = np.sum((imageA.astype("float") - imageB.astype("float")) ** 2)
	err /= float(imageA.shape[0] * imageA.shape[1])
	
	# return the MSE, the lower the error, the more "similar"
	# the two images are
	return err
for i in range(0,20):
    exist=os.path.isfile("eight/adv_eight_{0}.gv.png".format(i))
    if exist:
        i1 = cv2.imread("eight/adv_eight_{0}.gv.png".format(i))
        i2 = cv2.imread("eight/or_eight_{0}.gv.png".format(i))
        x1=cv2.resize(i1, (100, 50))
        x2=cv2.resize(i2, (100, 50))
        x=mse(x1,x2)
        #print(str(i)+"->"+str(x))
        print(x)
# Out:
# 20114.703
# 19168.379
# 12845.3914
# 8050.1678
# 12353.765
# 20577.1206
# 14009.8698
# 14079.2752
# 13155.5366
# 7367.1606
# 18048.3966
# 19416.062
# 5216.8816
# 14524.7018
# 16400.4944
# 7686.2764
# 23823.3464

# %%
#from skimage.measure import structural_similarity as ssi
from skimage.measure import compare_ssim
import matplotlib.pyplot as plt
import numpy as np
import cv2
from pathlib import Path
def mse(imageA, imageB):
	# the 'Mean Squared Error' between the two images is the
	# sum of the squared difference between the two images;
	# NOTE: the two images must have the same dimension
	err = np.sum((imageA.astype("float") - imageB.astype("float")) ** 2)
	err /= float(imageA.shape[0] * imageA.shape[1])
	
	# return the MSE, the lower the error, the more "similar"
	# the two images are
	return err
for i in range(0,20):
    exist=os.path.isfile("nine/adv_nine_{0}.gv.png".format(i))
    if exist:
        i1 = cv2.imread("nine/adv_nine_{0}.gv.png".format(i))
        i2 = cv2.imread("nine/or_nine_{0}.gv.png".format(i))
        x1=cv2.resize(i1, (100, 50))
        x2=cv2.resize(i2, (100, 50))
        x=mse(x1,x2)
        #print(str(i)+"->"+str(x))
        print(x)
# Out:
# 6851.8722
# 8727.9926
# 26119.638
# 15580.4422
# 6021.982
# 6492.7692
# 13659.4448
# 18445.668
# 8010.836
# 15250.9128
# 7656.6172
# 14635.6778
# 18264.1854
# 14673.3068
# 18275.8198
# 20251.2178
# 15486.294
# 16345.0704
